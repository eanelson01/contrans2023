# %%
import numpy as np
import pandas as pd
import requests 
import os
import json

# %%
congressapi = os.getenv('congressapi')
opensecretsapi = os.getenv('opensecretsapi')

# %% [markdown]
# ## Congress Bills API for the 118th Congress

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
endpoint = f'/bill/{congress}'

# %%
parameters = {'format': 'json',
             'offset': 0,
             'limit': 250,
             'sort': 'updateDate+desc',
             'api_key': congressapi}

# %%
# This URL gives back the User Agent
# Use this anytime you want to get your User Agent
r = requests.get('http://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

# %%
headers = {'User-Agent': useragent,
          'From': 'ean8fr@virginia.edu'}

# %%
r = requests.get(root + endpoint, 
                params = parameters,
                headers = headers)

# %%
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)

# %%
myjson['bills'][3]['number']
# Out:
# '3935'

# %%
[x['number'] for x in myjson['bills']]
# Out:
# ['475',
#  '354',
#  '353',
#  '3935',
#  '1418',
#  '2874',
#  '2873',
#  '2872',
#  '2871',
#  '929',
#  '1786',
#  '2870',
#  '4596',
#  '2869',
#  '3448',
#  '2868',
#  '4051',
#  '934',
#  '5110',
#  '764',
#  '1726',
#  '1245',
#  '615',
#  '2867',
#  '705',
#  '2872',
#  '3371',
#  '1530',
#  '2670',
#  '2866',
#  '2865',
#  '2864',
#  '2862',
#  '2863',
#  '704',
#  '2860',
#  '2861',
#  '2859',
#  '2857',
#  '2858',
#  '2855',
#  '2856',
#  '4366',
#  '5608',
#  '5602',
#  '708',
#  '711',
#  '5590',
#  '709',
#  '5601',
#  '5588',
#  '706',
#  '5603',
#  '5593',
#  '65',
#  '5591',
#  '5584',
#  '5586',
#  '5599',
#  '5589',
#  '5609',
#  '5598',
#  '5600',
#  '707',
#  '5592',
#  '5582',
#  '5605',
#  '5612',
#  '5611',
#  '5607',
#  '5604',
#  '5610',
#  '5595',
#  '5594',
#  '5583',
#  '5587',
#  '710',
#  '5585',
#  '5606',
#  '5596',
#  '5613',
#  '66',
#  '5597',
#  '5614',
#  '5581',
#  '5501',
#  '352',
#  '351',
#  '238',
#  '2854',
#  '3511',
#  '2853',
#  '350',
#  '2850',
#  '5153',
#  '112',
#  '5134',
#  '5133',
#  '5106',
#  '5101',
#  '5099',
#  '5091',
#  '5089',
#  '2849',
#  '14',
#  '5052',
#  '5062',
#  '5059',
#  '5057',
#  '5044',
#  '5043',
#  '5041',
#  '2852',
#  '5031',
#  '5030',
#  '680',
#  '4365',
#  '4935',
#  '4845',
#  '4838',
#  '2851',
#  '4835',
#  '4831',
#  '4815',
#  '4746',
#  '4739',
#  '4706',
#  '4163',
#  '2847',
#  '2848',
#  '2846',
#  '2845',
#  '2844',
#  '2843',
#  '2842',
#  '4984',
#  '3200',
#  '2838',
#  '3107',
#  '1657',
#  '2841',
#  '663',
#  '3981',
#  '2839',
#  '349',
#  '2840',
#  '2837',
#  '2836',
#  '698',
#  '5552',
#  '5537',
#  '5564',
#  '5561',
#  '5573',
#  '5570',
#  '5556',
#  '5557',
#  '5579',
#  '5565',
#  '701',
#  '5571',
#  '5562',
#  '700',
#  '5575',
#  '5558',
#  '5580',
#  '5578',
#  '703',
#  '5559',
#  '5555',
#  '5563',
#  '5574',
#  '5566',
#  '5577',
#  '5572',
#  '5560',
#  '5576',
#  '5569',
#  '5568',
#  '702',
#  '5567',
#  '14',
#  '699',
#  '684',
#  '5525',
#  '1130',
#  '5548',
#  '348',
#  '347',
#  '334',
#  '2795',
#  '2835',
#  '1648',
#  '2834',
#  '2833',
#  '2832',
#  '346',
#  '2828',
#  '2831',
#  '2830',
#  '2827',
#  '1450',
#  '1435',
#  '2829',
#  '5538',
#  '5529',
#  '5531',
#  '691',
#  '5549',
#  '5551',
#  '5554',
#  '5536',
#  '692',
#  '5524',
#  '5539',
#  '5523',
#  '5535',
#  '694',
#  '5522',
#  '5530',
#  '5521',
#  '5550',
#  '5533',
#  '90',
#  '5543',
#  '5544',
#  '5545',
#  '5547',
#  '5528',
#  '5541',
#  '693',
#  '5526',
#  '5527',
#  '695',
#  '5546',
#  '5534',
#  '5553',
#  '5542',
#  '5532',
#  '5540',
#  '697',
#  '696',
#  '532',
#  '5517',
#  '5497',
#  '5473',
#  '5465',
#  '5457',
#  '9',
#  '2544']

# %%
# Saving the data to a local JSON file
with open('bills.json', 'w') as f:
    json.dump(myjson, f)

# %%
billsdf = pd.json_normalize(myjson, 
                           record_path = ['bills'])

# %%
billsdf
# Out:
#      congress number originChamber originChamberCode  \
# 0         118    475        Senate                 S
# 1         118    354        Senate                 S
# 2         118    353        Senate                 S
# 3         118   3935         House                 H
# 4         118   1418         House                 H
# ..        ...    ...           ...               ...
# 245       118   5473         House                 H
# 246       118   5465         House                 H
# 247       118   5457         House                 H
# 248       118      9        Senate                 S
# 249       118   2544         House                 H
#
#                                                  title   type  updateDate  \
# 0    A bill to designate the clinic of the Departme...      S  2023-09-21
# 1    A resolution congratulating the Louisiana Stat...   SRES  2023-09-21
# 2    A resolution expressing support for the design...   SRES  2023-09-21
# 3    Securing Growth and Robust Leadership in Ameri...     HR  2023-09-21
# 4    Animal Drug and Animal Generic Drug User Fee A...     HR  2023-09-21
# ..                                                 ...    ...         ...
# 245          Promoting Resilient Buildings Act of 2023     HR  2023-09-20
# 246   Congressional Access to Bureaucratic Offices Act     HR  2023-09-21
# 247  Carbon Dioxide Removal Research and Developmen...     HR  2023-09-20
# 248  A joint resolution providing for congressional...  SJRES  2023-09-20
# 249  Securing the U.S. Organ Procurement and Transp...     HR  2023-09-20
#
#     updateDateIncludingText  \
# 0      2023-09-21T19:43:44Z
# 1      2023-09-21T12:13:40Z
# 2      2023-09-21T12:13:40Z
# 3      2023-09-21T04:13:50Z
# 4      2023-09-21T04:13:50Z
# ..                      ...
# 245    2023-09-20T13:40:22Z
# 246    2023-09-21T11:30:24Z
# 247    2023-09-20T13:40:22Z
# 248    2023-09-20T14:08:25Z
# 249    2023-09-20T14:04:13Z
#
#                                                    url  \
# 0    https://api.congress.gov/v3/bill/118/s/475?for...
# 1    https://api.congress.gov/v3/bill/118/sres/354?...
# 2    https://api.congress.gov/v3/bill/118/sres/353?...
# 3    https://api.congress.gov/v3/bill/118/hr/3935?f...
# 4    https://api.congress.gov/v3/bill/118/hr/1418?f...
# ..                                                 ...
# 245  https://api.congress.gov/v3/bill/118/hr/5473?f...
# 246  https://api.congress.gov/v3/bill/118/hr/5465?f...
# 247  https://api.congress.gov/v3/bill/118/hr/5457?f...
# 248  https://api.congress.gov/v3/bill/118/sjres/9?f...
# 249  https://api.congress.gov/v3/bill/118/hr/2544?f...
#
#     latestAction.actionDate  \
# 0                2023-09-21
# 1                2023-09-20
# 2                2023-09-20
# 3                2023-09-20
# 4                2023-09-20
# ..                      ...
# 245              2023-09-15
# 246              2023-09-15
# 247              2023-09-15
# 248              2023-09-14
# 249              2023-09-14
#
#                                      latestAction.text latestAction.actionTime
# 0                              Presented to President.                     NaN
# 1    Submitted in the Senate, considered, and agree...                     NaN
# 2    Submitted in the Senate, considered, and agree...                     NaN
# 3    Read the first time. Placed on Senate Legislat...                     NaN
# 4    Read twice. Placed on Senate Legislative Calen...                     NaN
# ..                                                 ...                     ...
# 245  Referred to the Subcommittee on Economic Devel...                     NaN
# 246  Referred to the Subcommittee on Economic Devel...                     NaN
# 247  Referred to the Subcommittee on Water Resource...                     NaN
# 248                            Presented to President.                     NaN
# 249                            Presented to President.                     NaN
#
# [250 rows x 12 columns]

# %%
# Open Secrets API
root = 'http://www.opensecrets.org/api/'
parameters = {'method': 'getLegislators',
             'apikey': opensecretsapi,
             'id': 'VA',
             'output': 'json'}
r = requests.get(root, 
                 params = parameters, 
                 headers = headers)

# %%
myjson = json.loads(r.text)

# %% [markdown]
# 9/28/23

# %%
# Getting House Bills
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 'hr'
endpoint = f'/bill/{congress}/{bill_type}'

r = requests.get('http://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

headers = {'User-Agent': useragent,
          'From': 'ean8fr@virginia.edu'}

house_bills = []

for i in range(0, 1001, 250):
    parameters = {'format': 'json',
                 'offset': i,
                 'limit': 250,
                 'sort': 'updateDate+desc',
                 'api_key': congressapi}
    r = requests.get(root + endpoint,
                    params = parameters,
                    headers = headers)

    myjson = json.loads(r.text)
    bills = myjson['bills']
    house_bills.append(bills)

# %%
df1 = pd.DataFrame.from_dict(house_bills[0])
df2 = pd.DataFrame.from_dict(house_bills[1])
df3 = pd.DataFrame.from_dict(house_bills[2])
df4 = pd.DataFrame.from_dict(house_bills[3])
df5 = pd.DataFrame.from_dict(house_bills[4])
frames = [df1, df2, df3, df4, df5]
house_bills = pd.concat(frames, ignore_index= True)

# %%
# Getting Senate Bills
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 's'
endpoint = f'/bill/{congress}/{bill_type}'

r = requests.get('http://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

headers = {'User-Agent': useragent,
          'From': 'ean8fr@virginia.edu'}

senate_bills = []

for i in range(0, 1001, 250):
    parameters = {'format': 'json',
                 'offset': i,
                 'limit': 250,
                 'sort': 'updateDate+desc',
                 'api_key': congressapi}
    r = requests.get(root + endpoint,
                    params = parameters,
                    headers = headers)

    myjson = json.loads(r.text)
    bills = myjson['bills']
    senate_bills.append(bills)

df1 = pd.DataFrame.from_dict(senate_bills[0])
df2 = pd.DataFrame.from_dict(senate_bills[1])
df3 = pd.DataFrame.from_dict(senate_bills[2])
df4 = pd.DataFrame.from_dict(senate_bills[3])
df5 = pd.DataFrame.from_dict(senate_bills[4])
frames = [df1, df2, df3, df4, df5]
senate_bills = pd.concat(frames, ignore_index= True)

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 's' 
cosponsors = []

for i in range(0, 100):
    if i % 10 == 0:
        print(f"Collecting bill number {i}")
    bill_number = senate_bills.iloc[i]['number']
    endpoint = f'/bill/{congress}/{bill_type}/{bill_number}/cosponsors'
    parameters = {'format': 'json',
                 'sort': 'updateDate+desc',
                 'api_key': congressapi}
    r = requests.get(root + endpoint,
                    params = parameters,
                    headers = headers)

    myjson = json.loads(r.text)
    cosponsor = myjson['cosponsors']
    cosponsors.append({'Bill Number': f'S {bill_number}', 
                       'Cosponsors': cosponsor})
cosponsors = pd.DataFrame.from_dict(cosponsors)
cosponsors
# Out:
# Collecting bill number 0
# Collecting bill number 10
# Collecting bill number 20
# Collecting bill number 30
# Collecting bill number 40
# Collecting bill number 50
# Collecting bill number 60
# Collecting bill number 70
# Collecting bill number 80
# Collecting bill number 90
#    Bill Number                                         Cosponsors
# 0       S 2961  [{'bioguideId': 'B001288', 'firstName': 'Cory'...
# 1       S 2960  [{'bioguideId': 'S001203', 'firstName': 'Tina'...
# 2        S 654  [{'bioguideId': 'B001288', 'firstName': 'Cory'...
# 3       S 2959                                                 []
# 4       S 2958                                                 []
# ..         ...                                                ...
# 95      S 2875                                                 []
# 96      S 1657  [{'bioguideId': 'K000377', 'firstName': 'Mark'...
# 97      S 2216                                                 []
# 98      S 1097  [{'bioguideId': 'F000062', 'firstName': 'Diann...
# 99      S 2149                                                 []
#
# [100 rows x 2 columns]

# %%
# Open Secrets API for VA
root = 'http://www.opensecrets.org/api/'
parameters = {'method': 'getLegislators',
             'apikey': opensecretsapi,
             'id': 'VA',
             'output': 'json'}

headers = {'User-Agent': useragent,
          'From': 'ean8fr@virginia.edu'}

r = requests.get(root, 
                 params = parameters, 
                 headers = headers)
myjson = json.loads(r.text)
# Out:
# {'response': {'legislator': [{'@attributes': {'cid': 'N00029459',
#      'firstlast': 'Rob Wittman',
#      'lastname': 'Wittman',
#      'party': 'R',
#      'office': 'VA01',
#      'gender': 'M',
#      'first_elected': '2007',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-4261',
#      'fax': '202-225-4382',
#      'website': 'http://wittman.house.gov',
#      'webform': 'https://wittman.house.gov/contact-form/',
#      'congress_office': '2055 Rayburn House Office Building',
#      'bioguide_id': 'W000804',
#      'votesmart_id': '58133',
#      'feccandid': 'H8VA01147',
#      'twitter_id': 'RobWittman',
#      'youtube_url': 'https://youtube.com/RobWittman',
#      'facebook_id': 'RepRobWittman',
#      'birthdate': '1959-02-03'}},
#    {'@attributes': {'cid': 'N00048315',
#      'firstlast': 'Jen Kiggans',
#      'lastname': 'Kiggans',
#      'party': 'R',
#      'office': 'VA02',
#      'gender': 'F',
#      'first_elected': '2022',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '',
#      'fax': '',
#      'website': '',
#      'webform': '',
#      'congress_office': '',
#      'bioguide_id': 'K000399',
#      'votesmart_id': '',
#      'feccandid': 'H2VA02064',
#      'twitter_id': '',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': ''}},
#    {'@attributes': {'cid': 'N00002147',
#      'firstlast': 'Bobby Scott',
#      'lastname': 'Scott',
#      'party': 'D',
#      'office': 'VA03',
#      'gender': 'M',
#      'first_elected': '1992',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-8351',
#      'fax': '202-225-8354',
#      'website': 'http://bobbyscott.house.gov',
#      'webform': 'https://bobbyscott.house.gov/email-bobby-scott',
#      'congress_office': '1201 Longworth House Office Building',
#      'bioguide_id': 'S000185',
#      'votesmart_id': '27117',
#      'feccandid': 'H6VA01117',
#      'twitter_id': 'BobbyScott',
#      'youtube_url': 'https://youtube.com/repbobbyscott',
#      'facebook_id': 'RepBobbyScott',
#      'birthdate': '1947-04-30'}},
#    {'@attributes': {'cid': 'N00051961',
#      'firstlast': 'Jennifer McClellan',
#      'lastname': 'McClellan',
#      'party': 'D',
#      'office': 'VA04',
#      'gender': 'F',
#      'first_elected': '2023',
#      'exit_code': '0',
#      'comments': 'Elected in special to replace McEachin',
#      'phone': '',
#      'fax': '',
#      'website': '',
#      'webform': '',
#      'congress_office': '',
#      'bioguide_id': '',
#      'votesmart_id': '',
#      'feccandid': '',
#      'twitter_id': '',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': ''}},
#    {'@attributes': {'cid': 'N00045557',
#      'firstlast': 'Bob Good',
#      'lastname': 'Good',
#      'party': 'R',
#      'office': 'VA05',
#      'gender': 'M',
#      'first_elected': '2020',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202225-4711',
#      'fax': '202225-5681',
#      'website': 'https://good.house.gov/',
#      'webform': '',
#      'congress_office': '1213 Longworth House Office Building, Washington, DC 20515',
#      'bioguide_id': '456853',
#      'votesmart_id': '',
#      'feccandid': '',
#      'twitter_id': '@RepBobGood',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': '09/11/65'}},
#    {'@attributes': {'cid': 'N00042296',
#      'firstlast': 'Ben Cline',
#      'lastname': 'Cline',
#      'party': 'R',
#      'office': 'VA06',
#      'gender': 'M',
#      'first_elected': '2018',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-5431',
#      'fax': '',
#      'website': 'https://cline.house.gov/',
#      'webform': '',
#      'congress_office': '1009 Longworth House Office Building',
#      'bioguide_id': 'C001118',
#      'votesmart_id': '',
#      'feccandid': '',
#      'twitter_id': 'RepBenCline',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': '1972-02-29'}},
#    {'@attributes': {'cid': 'N00041418',
#      'firstlast': 'Abigail Spanberger',
#      'lastname': 'Spanberger',
#      'party': 'D',
#      'office': 'VA07',
#      'gender': 'F',
#      'first_elected': '2018',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-2815',
#      'fax': '',
#      'website': 'https://spanberger.house.gov/',
#      'webform': '',
#      'congress_office': '1239 Longworth House Office Building',
#      'bioguide_id': 'S001209',
#      'votesmart_id': '',
#      'feccandid': '',
#      'twitter_id': 'RepSpanberger',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': '1979-08-07'}},
#    {'@attributes': {'cid': 'N00036018',
#      'firstlast': 'Don Beyer',
#      'lastname': 'Beyer',
#      'party': 'D',
#      'office': 'VA08',
#      'gender': 'M',
#      'first_elected': '2014',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-4376',
#      'fax': '202-225-0017',
#      'website': 'http://beyer.house.gov',
#      'webform': '',
#      'congress_office': '1119 Longworth House Office Building',
#      'bioguide_id': 'B001292',
#      'votesmart_id': '',
#      'feccandid': 'H4VA08224',
#      'twitter_id': 'repdonbeyer',
#      'youtube_url': '',
#      'facebook_id': 'repdonbeyer',
#      'birthdate': '1950-06-20'}},
#    {'@attributes': {'cid': 'N00032029',
#      'firstlast': 'Morgan Griffith',
#      'lastname': 'Griffith',
#      'party': 'R',
#      'office': 'VA09',
#      'gender': 'M',
#      'first_elected': '2010',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-3861',
#      'fax': '202-225-0076',
#      'website': 'http://morgangriffith.house.gov',
#      'webform': 'https://morgangriffith.house.gov/contact/contactform.htm',
#      'congress_office': '2202 Rayburn House Office Building',
#      'bioguide_id': 'G000568',
#      'votesmart_id': '5148',
#      'feccandid': 'H0VA09055',
#      'twitter_id': 'RepMGriffith',
#      'youtube_url': 'https://youtube.com/RepMorganGriffith',
#      'facebook_id': 'RepMorganGriffith',
#      'birthdate': '1958-03-15'}},
#    {'@attributes': {'cid': 'N00041002',
#      'firstlast': 'Jennifer Wexton',
#      'lastname': 'Wexton',
#      'party': 'D',
#      'office': 'VA10',
#      'gender': 'F',
#      'first_elected': '2018',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-5136',
#      'fax': '',
#      'website': 'https://wexton.house.gov/',
#      'webform': '',
#      'congress_office': '1217 Longworth House Office Building',
#      'bioguide_id': 'W000825',
#      'votesmart_id': '',
#      'feccandid': '',
#      'twitter_id': 'RepWexton',
#      'youtube_url': '',
#      'facebook_id': '',
#      'birthdate': '1968-05-27'}},
#    {'@attributes': {'cid': 'N00029891',
#      'firstlast': 'Gerry Connolly',
#      'lastname': 'Connolly',
#      'party': 'D',
#      'office': 'VA11',
#      'gender': 'M',
#      'first_elected': '2008',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-225-1492',
#      'fax': '202-225-3071',
#      'website': 'https://connolly.house.gov',
#      'webform': 'https://forms.house.gov/connolly/contact-form.shtml',
#      'congress_office': '2238 Rayburn House Office Building',
#      'bioguide_id': 'C001078',
#      'votesmart_id': '95078',
#      'feccandid': 'H8VA11062',
#      'twitter_id': 'GerryConnolly',
#      'youtube_url': 'https://youtube.com/repconnolly',
#      'facebook_id': 'CongressmanGerryConnolly',
#      'birthdate': '1950-03-30'}},
#    {'@attributes': {'cid': 'N00033177',
#      'firstlast': 'Tim Kaine',
#      'lastname': 'Kaine',
#      'party': 'D',
#      'office': 'VAS1',
#      'gender': 'M',
#      'first_elected': '2012',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-224-4024',
#      'fax': '202-228-6363',
#      'website': 'https://www.kaine.senate.gov',
#      'webform': 'https://www.kaine.senate.gov/contact',
#      'congress_office': '231 Russell Senate Office Building',
#      'bioguide_id': 'K000384',
#      'votesmart_id': '50772',
#      'feccandid': 'S2VA00142',
#      'twitter_id': 'SenKaineOffice',
#      'youtube_url': 'https://youtube.com/SenatorTimKaine',
#      'facebook_id': 'SenatorKaine',
#      'birthdate': '1958-02-26'}},
#    {'@attributes': {'cid': 'N00002097',
#      'firstlast': 'Mark Warner',
#      'lastname': 'Warner',
#      'party': 'D',
#      'office': 'VAS2',
#      'gender': 'M',
#      'first_elected': '2008',
#      'exit_code': '0',
#      'comments': '',
#      'phone': '202-224-2023',
#      'fax': '202-224-6295',
#      'website': 'https://www.warner.senate.gov',
#      'webform': 'http://www.warner.senate.gov/public/index.cfm?p=Contact',
#      'congress_office': '703 Hart Senate Office Building',
#      'bioguide_id': 'W000805',
#      'votesmart_id': '535',
#      'feccandid': 'S6VA00093',
#      'twitter_id': 'MarkWarner',
#      'youtube_url': 'https://youtube.com/SenatorMarkWarner',
#      'facebook_id': 'MarkRWarner',
#      'birthdate': '1954-12-15'}}]}}

# %%
cids = []
for i in range(0,len(myjson['response']['legislator'])):
    cid = myjson['response']['legislator'][i]['@attributes']['cid']
    cids.append(cid)
cids
# Out:
# ['N00029459',
#  'N00048315',
#  'N00002147',
#  'N00051961',
#  'N00045557',
#  'N00042296',
#  'N00041418',
#  'N00036018',
#  'N00032029',
#  'N00041002',
#  'N00029891',
#  'N00033177',
#  'N00002097']

# %%
financial_information = []
for i in range(len(cids)):
    parameters = {'method': 'memPFDprofile',
                 'apikey': opensecretsapi,
                 'id': 'VA',
                  'cid': cids[i],
                 'output': 'json'}
    r = requests.get(root, 
                     params = parameters, 
                     headers = headers)
    myjson = json.loads(r.text)
    data = myjson['response']['member_profile']
    financial_information.append({'cid': cids[i],
                                  'Finaicial Information': data})

# %%
financial_information = pd.DataFrame.from_dict(financial_information)
financial_information
# Out:
#           cid                              Finaicial Information
# 0   N00029459  {'@attributes': {'name': 'Wittman, Rob', 'data...
# 1   N00048315  {'@attributes': {'name': '', 'data_year': '201...
# 2   N00002147  {'@attributes': {'name': 'Scott, Bobby', 'data...
# 3   N00051961  {'@attributes': {'name': '', 'data_year': '201...
# 4   N00045557  {'@attributes': {'name': '', 'data_year': '201...
# 5   N00042296  {'@attributes': {'name': '', 'data_year': '201...
# 6   N00041418  {'@attributes': {'name': '', 'data_year': '201...
# 7   N00036018  {'@attributes': {'name': '', 'data_year': '201...
# 8   N00032029  {'@attributes': {'name': 'Griffith, Morgan', '...
# 9   N00041002  {'@attributes': {'name': '', 'data_year': '201...
# 10  N00029891  {'@attributes': {'name': 'Connolly, Gerry', 'd...
# 11  N00033177  {'@attributes': {'name': '', 'data_year': '201...
# 12  N00002097  {'@attributes': {'name': 'Warner, Mark', 'data...
