# %%
import numpy as np
import pandas as pd
import os
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
import psycopg2 
from sqlalchemy import create_engine

# %%
bills=pd.read_csv('Data/bills.csv')  
committee_members=pd.read_csv('Data/committee_members.csv')  
committees=pd.read_csv('Data/committees.csv')  
congress_members=pd.read_csv('Data/congress_members.csv') 
leadership=pd.read_csv('Data/leadership.csv')  
os_contributions=pd.read_csv('Data/os_contributions.csv')  
os_legislators=pd.read_csv('Data/os_legislators.csv')  
terms=pd.read_csv('Data/terms.csv')  
votingaffinity=pd.read_csv('Data/votingaffinity.csv')

# %% [markdown]
# # Bills

# %%
bills.columns = [x.lower() for x in bills.columns]
bills.columns = [x.replace('.', '_') for x in bills.columns]
bills.columns
# Out:
# Index(['congress', 'introduceddate', 'number', 'title', 'type', 'url',
#        'latestaction_actiondate', 'latestaction_text', 'policyarea_name',
#        'amendmentnumber', 'latestaction', 'latestaction_actiontime'],
#       dtype='object')

# %%
bills.head(3).T
# Out:
#                                                                          0  \
# congress                                                               118
# introduceddate                                                  2023-10-04
# number                                                               405.0
# title                    A resolution expressing support for the design...
# type                                                                  SRES
# url                      https://api.congress.gov/v3/bill/118/sres/405?...
# latestaction_actiondate                                         2023-10-04
# latestaction_text        Submitted in the Senate, considered, and agree...
# policyarea_name                         Armed Forces and National Security
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN
#
#                                                                          1  \
# congress                                                               118
# introduceddate                                                  2023-09-29
# number                                                              2998.0
# title                    Land-Grant Research Equity and Accountability Act
# type                                                                     S
# url                      https://api.congress.gov/v3/bill/118/s/2998?fo...
# latestaction_actiondate                                         2023-09-29
# latestaction_text        Read twice and referred to the Committee on Ag...
# policyarea_name                                       Agriculture and Food
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN
#
#                                                                          2
# congress                                                               118
# introduceddate                                                  2023-09-27
# number                                                               373.0
# title                    A resolution designating the week of September...
# type                                                                  SRES
# url                      https://api.congress.gov/v3/bill/118/sres/373?...
# latestaction_actiondate                                         2023-09-27
# latestaction_text        Submitted in the Senate, considered, and agree...
# policyarea_name                                                        NaN
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN

# %% [markdown]
# Primary key is congress, number, and type

# %% [markdown]
# # Congress Members

# %%
congress_members.columns = [x.lower() for x in congress_members.columns]
congress_members.columns = [x.replace('.', '_') for x in congress_members.columns]
congress_members.columns
# Out:
# Index(['bioguideid', 'birthyear', 'currentmember', 'directordername',
#        'firstname', 'honorificname', 'invertedordername', 'lastname',
#        'officialwebsiteurl', 'partyhistory', 'state', 'terms', 'updatedate',
#        'addressinformation_city', 'addressinformation_district',
#        'addressinformation_officeaddress', 'addressinformation_phonenumber',
#        'addressinformation_zipcode', 'cosponsoredlegislation_count',
#        'cosponsoredlegislation_url', 'depiction_attribution',
#        'depiction_imageurl', 'sponsoredlegislation_count',
#        'sponsoredlegislation_url', 'middlename', 'suffixname', 'nickname',
#        'leadership', 'district'],
#       dtype='object')

# %%
congress_members = congress_members.drop(['terms', 'leadership', 'partyhistory'], axis=1)

# %%
congress_members.head(3).T
# Out:
#                                                                                   0  \
# bioguideid                                                                  B000944
# birthyear                                                                      1952
# currentmember                                                                  True
# directordername                                                       Sherrod Brown
# firstname                                                                   Sherrod
# honorificname                                                                   Mr.
# invertedordername                                                    Brown, Sherrod
# lastname                                                                      Brown
# officialwebsiteurl                                    https://www.brown.senate.gov/
# state                                                                          Ohio
# updatedate                                                     2023-04-01T12:42:12Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  503 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-2315
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   7873
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/B000944/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/b000944_20...
# sponsoredlegislation_count                                                   1389.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/B000944/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN
#
#                                                                                   1  \
# bioguideid                                                                  C000127
# birthyear                                                                      1958
# currentmember                                                                  True
# directordername                                                      Maria Cantwell
# firstname                                                                     Maria
# honorificname                                                                   Ms.
# invertedordername                                                   Cantwell, Maria
# lastname                                                                   Cantwell
# officialwebsiteurl                                  https://www.cantwell.senate.gov
# state                                                                    Washington
# updatedate                                                     2023-04-01T12:42:12Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  511 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-3441
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   3923
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/C000127/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/c000127_20...
# sponsoredlegislation_count                                                    882.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/C000127/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN
#
#                                                                                   2
# bioguideid                                                                  C000141
# birthyear                                                                      1943
# currentmember                                                                  True
# directordername                                                  Benjamin L. Cardin
# firstname                                                                       Ben
# honorificname                                                                   Mr.
# invertedordername                                               Cardin, Benjamin L.
# lastname                                                                     Cardin
# officialwebsiteurl                                   https://www.cardin.senate.gov/
# state                                                                      Maryland
# updatedate                                                     2023-04-01T12:42:13Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  509 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-4524
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   6100
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/C000141/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/c000141_20...
# sponsoredlegislation_count                                                   1265.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/C000141/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN

# %% [markdown]
# Primary key is the bioguide_id
# There is not atomic data for partyhistory, terms, and leadership. We have a terms dataframe already though

# %% [markdown]
# ## Terms

# %%
terms.columns = [x.lower() for x in terms.columns]
terms.columns = [x.replace('.', '_') for x in terms.columns]
terms.columns
# Out:
# Index(['chamber', 'congress', 'endyear', 'membertype', 'startyear',
#        'statecode', 'statename', 'bioguideid', 'district'],
#       dtype='object')

# %%
terms.head(3).T
# Out:
#                   0        1        2
# chamber      Senate   Senate   Senate
# congress        107      108      109
# endyear      2003.0   2005.0   2007.0
# membertype  Senator  Senator  Senator
# startyear      2002     2003     2005
# statecode        TX       TX       TX
# statename     Texas    Texas    Texas
# bioguideid  C001056  C001056  C001056
# district        NaN      NaN      NaN

# %% [markdown]
# Primary key is bioguideid and congress

# %% [markdown]
# ## Leadership

# %%
leadership.columns = [x.lower() for x in leadership.columns]
leadership.columns = [x.replace('.', '_') for x in leadership.columns]
leadership.columns
# Out:
# Index(['congress', 'type', 'bioguideid', 'current'], dtype='object')

# %%
leadership.head(3).T
# Out:
#                                       0                          1  \
# congress                            113                        114
# type        Assistant Democratic Leader  Assistant Majority Leader
# bioguideid                      C001056                    C001056
# current                             NaN                        NaN
#
#                         2
# congress              115
# type        Majority Whip
# bioguideid        C001056
# current               NaN

# %% [markdown]
# # os_legislators

# %%
os_legislators.columns = [x.lower() for x in os_legislators.columns]
os_legislators.columns = [x.replace('.', '_') for x in os_legislators.columns]
os_legislators = os_legislators.drop_duplicates()
os_legislators.columns
# Out:
# Index(['cid', 'firstl', 'lastnam', 'party', 'offic', 'gend', 'first_elected',
#        'xit_cod', 'commen', 'phon', 'fax', 'w', 'webform', 'congress_offic',
#        'oguide_id', 'votesmart_id', 'feccandid', 'witter_id', 'youtube_url',
#        'facebook_id', 'hd'],
#       dtype='object')

# %%
newbio = ['B001311','B001313','B001314','B001315','C001125',
          'C001126','C001127','C001129','E000071','F000475','G000061',
          'G000551','G000595','H001093','L000595','L000597','M000687',
          'M001210','M001217','M001227','R000579','R000618',
          'S001218','T000165','T000488','P000619']
legs = ['Dan Bishop','Shontel Brown','Aaron Bean','Nikki Budzinski',
        'Troy Carter','Mike Carey','Sheila Cherfilus-McCormick',
        'Mike Collins','Jake Ellzey','Brad Finstad','Mike Garcia',
        'Raul M Grijalva','Bob Good','Erin Houchin','Julia Letlow',
        'Laurel Lee','Kweisi Mfume','Greg Murphy','Jared Moskowitz',
        'Jennifer McClellan','Pat Ryan','Pete Ricketts','Melanie Stansbury',
        'Tom Tiffany','Shri Thanedar','Mary Peltola']
def replacebio(b,n):
    os_legislators.loc[os_legislators['firstl']==n, 'oguide_id'] = b
for b, n in zip(newbio, legs):
    replacebio(b,n)

# %%
os_legislators = os_legislators[['cid', 'party', 'oguide_id']]
os_legislators = os_legislators.rename({'oguide_id': 'bioguideid'}, axis = 1)

# %%
os_legislators
# Out:
#            cid party bioguideid
# 0    N00050780     D    P000619
# 1    N00035774     R    S001198
# 2    N00026050     R    M001153
# 3    N00044245     R    C001054
# 4    N00041295     R    M001212
# ..         ...   ...        ...
# 532  N00032838     D    M001183
# 533  N00009771     R    C001047
# 534  N00049197     R    H001096
# 535  N00006236     R    B001261
# 536  N00029788     R    L000571
#
# [536 rows x 3 columns]

# %% [markdown]
# Primary key is either bioguideid or cid. Because it shares with congress_members, merge them

# %%
members = pd.merge(congress_members, os_legislators,
                  on = 'bioguideid',
                  how = 'outer',
                  validate = 'one_to_one',
                  indicator = 'matched')

# %%
members['matched'].value_counts()
# Out:
# matched
# both          530
# left_only       7
# right_only      6
# Name: count, dtype: int64

# %%
members.query("matched == 'left_only'")
# Out:
#     bioguideid  birthyear currentmember                 directordername  \
# 120    N000147     1937.0          True           Eleanor Holmes Norton
# 133    S001177     1955.0          True  Gregorio Kilili Camacho Sablan
# 248    P000610     1966.0          True              Stacey E. Plaskett
# 252    R000600     1947.0          True   Aumua Amata Coleman Radewagen
# 293    G000582     1976.0          True        Jenniffer González-Colón
# 478    M001219     1962.0          True                 James C. Moylan
# 536    B001320     1979.0          True              Laphonza R. Butler
#
#        firstname honorificname                invertedordername  \
# 120      ELEANOR           NaN           Norton, Eleanor Holmes
# 133     Gregorio           NaN  Sablan, Gregorio Kilili Camacho
# 248       Stacey           Ms.              Plaskett, Stacey E.
# 252  Aumua Amata          Mrs.   Radewagen, Aumua Amata Coleman
# 293    Jenniffer          Miss        González-Colón, Jenniffer
# 478        James           NaN                 Moylan, James C.
# 536     Laphonza           Ms.              Butler, Laphonza R.
#
#            lastname                officialwebsiteurl  \
# 120          NORTON         https://norton.house.gov/
# 133          Sablan         https://sablan.house.gov/
# 248        Plaskett       https://plaskett.house.gov/
# 252       Radewagen      https://radewagen.house.gov/
# 293  Gonzalez-Colon  https://gonzalez-colon.house.gov
# 478          Moylan          https://moylan.house.gov
# 536          Butler    https://www.butler.senate.gov/
#
#                         state  ...  \
# 120      District of Columbia  ...
# 133  Northern Mariana Islands  ...
# 248            Virgin Islands  ...
# 252            American Samoa  ...
# 293               Puerto Rico  ...
# 478                      Guam  ...
# 536                California  ...
#
#                                     depiction_imageurl  \
# 120  https://www.congress.gov/img/member/116_dg_dc_...
# 133  https://www.congress.gov/img/member/s001177_20...
# 248  https://www.congress.gov/img/member/116_dg_vi_...
# 252  https://www.congress.gov/img/member/r000600_20...
# 293  https://www.congress.gov/img/member/g000582_20...
# 478  https://www.congress.gov/img/member/m001219_20...
# 536                                                NaN
#
#     sponsoredlegislation_count  \
# 120                      975.0
# 133                      149.0
# 248                      112.0
# 252                       35.0
# 293                      161.0
# 478                       12.0
# 536                        NaN
#
#                               sponsoredlegislation_url      middlename  \
# 120  https://api.congress.gov/v3/member/N000147/spo...          HOLMES
# 133  https://api.congress.gov/v3/member/S001177/spo...  Kilili Camacho
# 248  https://api.congress.gov/v3/member/P000610/spo...              E.
# 252  https://api.congress.gov/v3/member/R000600/spo...         Coleman
# 293  https://api.congress.gov/v3/member/G000582/spo...             NaN
# 478  https://api.congress.gov/v3/member/M001219/spo...              C.
# 536                                                NaN             NaN
#
#     suffixname  nickname  district  cid party    matched
# 120        NaN       NaN       NaN  NaN   NaN  left_only
# 133        NaN       NaN       NaN  NaN   NaN  left_only
# 248        NaN       NaN       NaN  NaN   NaN  left_only
# 252        NaN       NaN       NaN  NaN   NaN  left_only
# 293        NaN       NaN       NaN  NaN   NaN  left_only
# 478        NaN       NaN       NaN  NaN   NaN  left_only
# 536        NaN       NaN       NaN  NaN   NaN  left_only
#
# [7 rows x 29 columns]

# %%
# people no longer in congress
members.query("matched == 'right_only'")
# Out:
#     bioguideid  birthyear currentmember directordername firstname  \
# 537    G000551        NaN           NaN             NaN       NaN
# 538    F000062        NaN           NaN             NaN       NaN
# 539    C001129        NaN           NaN             NaN       NaN
# 540    S001197        NaN           NaN             NaN       NaN
# 541    C001084        NaN           NaN             NaN       NaN
# 542    S001192        NaN           NaN             NaN       NaN
#
#     honorificname invertedordername lastname officialwebsiteurl state  ...  \
# 537           NaN               NaN      NaN                NaN   NaN  ...
# 538           NaN               NaN      NaN                NaN   NaN  ...
# 539           NaN               NaN      NaN                NaN   NaN  ...
# 540           NaN               NaN      NaN                NaN   NaN  ...
# 541           NaN               NaN      NaN                NaN   NaN  ...
# 542           NaN               NaN      NaN                NaN   NaN  ...
#
#     depiction_imageurl sponsoredlegislation_count sponsoredlegislation_url  \
# 537                NaN                        NaN                      NaN
# 538                NaN                        NaN                      NaN
# 539                NaN                        NaN                      NaN
# 540                NaN                        NaN                      NaN
# 541                NaN                        NaN                      NaN
# 542                NaN                        NaN                      NaN
#
#     middlename suffixname  nickname  district        cid party     matched
# 537        NaN        NaN       NaN       NaN  N00025284     D  right_only
# 538        NaN        NaN       NaN       NaN  N00007364     D  right_only
# 539        NaN        NaN       NaN       NaN  N00035370     R  right_only
# 540        NaN        NaN       NaN       NaN  N00035544     R  right_only
# 541        NaN        NaN       NaN       NaN  N00032019     D  right_only
# 542        NaN        NaN       NaN       NaN  N00033932     R  right_only
#
# [6 rows x 29 columns]

# %%
# once we have fixed the issue
members = pd.merge(congress_members, os_legislators,
                  on = 'bioguideid',
                  how = 'inner')

# %%
members
# Out:
#     bioguideid  birthyear  currentmember          directordername firstname  \
# 0      B000944       1952           True            Sherrod Brown   Sherrod
# 1      C000127       1958           True           Maria Cantwell     Maria
# 2      C000141       1943           True       Benjamin L. Cardin       Ben
# 3      C000174       1947           True         Thomas R. Carper    Thomas
# 4      C001070       1960           True      Robert P. Casey Jr.       Bob
# ..         ...        ...            ...                      ...       ...
# 525    G000600       1988           True  Marie Gluesenkamp Perez     Marie
# 526    V000135       1969           True        Derrick Van Orden   Derrick
# 527    H001096       1962           True       Harriet M. Hageman   Harriet
# 528    R000618       1964           True            Pete Ricketts      Pete
# 529    M001227       1972           True    Jennifer L. McClellan  Jennifer
#
#     honorificname         invertedordername   lastname  \
# 0             Mr.            Brown, Sherrod      Brown
# 1             Ms.           Cantwell, Maria   Cantwell
# 2             Mr.       Cardin, Benjamin L.     Cardin
# 3             Mr.         Carper, Thomas R.     Carper
# 4             Mr.     Casey, Robert P., Jr.      Casey
# ..            ...                       ...        ...
# 525           NaN  Perez, Marie Gluesenkamp      Perez
# 526           Mr.        Van Orden, Derrick  Van Orden
# 527           NaN       Hageman, Harriet M.    Hageman
# 528           Mr.            Ricketts, Pete   Ricketts
# 529           NaN    McClellan, Jennifer L.  McClellan
#
#                      officialwebsiteurl         state  ...  \
# 0         https://www.brown.senate.gov/          Ohio  ...
# 1       https://www.cantwell.senate.gov    Washington  ...
# 2        https://www.cardin.senate.gov/      Maryland  ...
# 3         https://www.carper.senate.gov      Delaware  ...
# 4         https://www.casey.senate.gov/  Pennsylvania  ...
# ..                                  ...           ...  ...
# 525  https://gluesenkampperez.house.gov    Washington  ...
# 526          https://vanorden.house.gov     Wisconsin  ...
# 527           https://hageman.house.gov       Wyoming  ...
# 528     https://www.ricketts.senate.gov      Nebraska  ...
# 529        https://mcclellan.house.gov/      Virginia  ...
#
#                                  depiction_attribution  \
# 0    <a href="http://www.senate.gov/artandhistory/h...
# 1    <a href="http://www.senate.gov/artandhistory/h...
# 2    <a href="http://www.senate.gov/artandhistory/h...
# 3    <a href="http://www.senate.gov/artandhistory/h...
# 4    <a href="http://www.senate.gov/artandhistory/h...
# ..                                                 ...
# 525                       Image courtesy of the Member
# 526                       Image courtesy of the Member
# 527                       Image courtesy of the Member
# 528                         Official U.S. Senate Photo
# 529                       Image courtesy of the Member
#
#                                     depiction_imageurl  \
# 0    https://www.congress.gov/img/member/b000944_20...
# 1    https://www.congress.gov/img/member/c000127_20...
# 2    https://www.congress.gov/img/member/c000141_20...
# 3    https://www.congress.gov/img/member/c000174_20...
# 4    https://www.congress.gov/img/member/c001070_20...
# ..                                                 ...
# 525  https://www.congress.gov/img/member/g000600_20...
# 526  https://www.congress.gov/img/member/v000135_20...
# 527  https://www.congress.gov/img/member/h001096_20...
# 528  https://www.congress.gov/img/member/r000618_20...
# 529  https://www.congress.gov/img/member/m001227_20...
#
#     sponsoredlegislation_count  \
# 0                       1389.0
# 1                        882.0
# 2                       1265.0
# 3                        769.0
# 4                       1180.0
# ..                         ...
# 525                       13.0
# 526                       14.0
# 527                       28.0
# 528                       17.0
# 529                        5.0
#
#                               sponsoredlegislation_url   middlename  \
# 0    https://api.congress.gov/v3/member/B000944/spo...          NaN
# 1    https://api.congress.gov/v3/member/C000127/spo...          NaN
# 2    https://api.congress.gov/v3/member/C000141/spo...          NaN
# 3    https://api.congress.gov/v3/member/C000174/spo...           R.
# 4    https://api.congress.gov/v3/member/C001070/spo...          NaN
# ..                                                 ...          ...
# 525  https://api.congress.gov/v3/member/G000600/spo...  Gluesenkamp
# 526  https://api.congress.gov/v3/member/V000135/spo...          NaN
# 527  https://api.congress.gov/v3/member/H001096/spo...           M.
# 528  https://api.congress.gov/v3/member/R000618/spo...          NaN
# 529  https://api.congress.gov/v3/member/M001227/spo...           L.
#
#      suffixname  nickname district        cid party
# 0           NaN       NaN      NaN  N00003535     D
# 1           NaN       NaN      NaN  N00007836     D
# 2           NaN       NaN      NaN  N00001955     D
# 3           NaN       NaN      NaN  N00012508     D
# 4           JR.       NaN      NaN  N00027503     D
# ..          ...       ...      ...        ...   ...
# 525         NaN       NaN      3.0  N00050490     D
# 526         NaN       NaN      3.0  N00046843     R
# 527         NaN       NaN      NaN  N00049197     R
# 528         NaN       NaN      NaN  N00027695     R
# 529         NaN       NaN      4.0  N00051961     D
#
# [530 rows x 28 columns]

# %% [markdown]
# # os_contributions

# %%
os_contributions.columns = [x.lower() for x in os_contributions.columns]
os_contributions.columns = [x.replace('.', '_') for x in os_contributions.columns]
os_contributions = os_contributions.rename({'otal': 'total', 
                                            'org_nam': 'org_name'}, axis = 1)
os_contributions.columns
# Out:
# Index(['org_name', 'total', 'pac', 'ndiv', 'cid'], dtype='object')

# %%
# Need to have cid in this table
os_contributions.head(30)
# Out:
#                                  org_name  total    pac   ndiv        cid
# 0                         State of Alaska  19541      0  19541  N00050780
# 1                 Sonosky, Chambers et al  16050      0  16050  N00050780
# 2               General Communication Inc  15150   2500  12650  N00050780
# 3                              Google Inc  14164      0  14164  N00050780
# 4          University of Alaska/Anchorage  13938      0  13938  N00050780
# 5                              Swing Left  13400      0  13400  N00050780
# 6                               Apple Inc  10783      0  10783  N00050780
# 7   Service Employees International Union  10010   5000   5010  N00050780
# 8                 National Education Assn  10000  10000      0  N00050780
# 9                           Sealaska Corp   9950      0   9950  N00050780
# 10                      Rpm International  66950  10000  56950  N00035774
# 11                          Goldman Sachs  59500   4000  55500  N00035774
# 12              Calfee, Halter & Griswold  45300      0  45300  N00035774
# 13    National Republican Senatorial Cmte  44600  44600      0  N00035774
# 14                       Trident Seafoods  43550   5600  37950  N00035774
# 15                     Elliott Management  39100      0  39100  N00035774
# 16                        General Atomics  37550  12500  25050  N00035774
# 17                         ConocoPhillips  37425  10000  27425  N00035774
# 18                       Blackstone Group  36100      0  36100  N00035774
# 19                             Lynden Inc  30700      0  30700  N00035774
# 20                         ConocoPhillips  60050  10000  50050  N00026050
# 21    American Israel Public Affairs Cmte  59500  10000  49500  N00026050
# 22                       Trident Seafoods  55300   5800  49500  N00026050
# 23    National Republican Senatorial Cmte  51200  51200      0  N00026050
# 24                               KKR & Co  48405      0  48405  N00026050
# 25                         NextEra Energy  36450  10000  26450  N00026050
# 26              General Communication Inc  34900  10000  24900  N00026050
# 27                            Exelon Corp  34300  11500  22800  N00026050
# 28                                 NorPAC  31250      0  31250  N00026050
# 29                          Capital Group  30700      0  30700  N00026050

# %% [markdown]
# # committees

# %%
committees.columns = [x.lower() for x in committees.columns]
committees.columns = [x.replace('.', '_') for x in committees.columns]
committees.columns
# Out:
# Index(['chamber', 'committeetypecode', 'name', 'systemcode', 'url',
#        'parent_name', 'parent_systemcode', 'parent_url', 'subcommittees'],
#       dtype='object')

# %%
committees = committees.drop(['subcommittees'], axis = 1)

# %%
committees['systemcode'] =  [x[:-2].upper() for x in committees['systemcode']]

# %%
committees.head(3).T
# Out:
#                                                                    0  \
# chamber                                                        House
# committeetypecode                                              Other
# name                                           Bicentenary Committee
# systemcode                                                      HCZA
# url                https://api.congress.gov/v3/committee/house/hc...
# parent_name                                                      NaN
# parent_systemcode                                                NaN
# parent_url                                                       NaN
#
#                                                                    1  \
# chamber                                                        House
# committeetypecode                                           Standing
# name                                       Energy (Ad Hoc) Committee
# systemcode                                                      HHAH
# url                https://api.congress.gov/v3/committee/house/hh...
# parent_name                                                      NaN
# parent_systemcode                                                NaN
# parent_url                                                       NaN
#
#                                                                    2
# chamber                                                        House
# committeetypecode                                             Select
# name                             U.S. Role in Iranian Arms Committee
# systemcode                                                      HLBZ
# url                https://api.congress.gov/v3/committee/house/hl...
# parent_name                                                      NaN
# parent_systemcode                                                NaN
# parent_url                                                       NaN

# %% [markdown]
# primary key is systemcode, subcommittees is not atomic but it is included already and can be dropped

# %% [markdown]
# # committee_members

# %%
committee_members.columns = [x.lower() for x in committee_members.columns]
committee_members.columns = [x.replace('.', '_') for x in committee_members.columns]
committee_members.columns
# Out:
# Index(['committee_code', 'rank', 'title', 'bioguide'], dtype='object')

# %%
committee_members.head(3).T
# Out:
#                       0               1        2
# committee_code     HSII            HSII     HSII
# rank                1.0             1.0      2.0
# title             Chair  Ranking Member      NaN
# bioguide        W000821         G000551  L000564

# %% [markdown]
# primary key is the committee_code and bioguideid

# %% [markdown]
# # voting_affinity

# %%
votingaffinity = pd.read_csv('Data/votingaffinity.csv')

# %%
votingaffinity
# Out:
#         icpsr  member_compare  affinity_score
# 0       14226           14435        0.305147
# 1       14226           14858        0.375000
# 2       14226           14871        0.352941
# 3       14226           14921        0.772059
# 4       14226           15015        0.356618
# ...       ...             ...             ...
# 204133  91980           31101        0.202532
# 204134  91980           31102        0.830018
# 204135  91980           31103        0.169982
# 204136  91980           39301        0.198915
# 204137  91980           39307        0.202532
#
# [204138 rows x 3 columns]

# %% [markdown]
# # Create the Databse

# %%
dbserver = psycopg2.connect(
    host = 'postgres',
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    port = 5432
)
dbserver.autocommit = True

# %%
cursor = dbserver.cursor()

# %%
try:
    cursor.execute("CREATE DATABASE congress")
except:
    cursor.execute("DROP DATABASE congress")
    cursor.execute("CREATE DATABASE congress")

# %%
engine = create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    host = 'postgres',
    port = 5432,
    db = 'congress'
))

# %% [markdown]
# We need to upload
#
# * members
# * bills
# * committess
# * committee_members
# * terms
# * leadership
# * contributions

# %%
print(members.shape[0])
members.to_sql('members', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 530
# 530

# %%
print(bills.shape[0])
bills.to_sql('bills', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 38325
# 38325

# %%
print(committees.shape[0])
committees.to_sql('committees', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 714
# 714

# %%
print(committee_members.shape[0])
committee_members.to_sql('committee_members', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 3866
# 3866

# %%
print(terms.shape[0])
terms.to_sql('terms', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 278
# 278

# %%
print(leadership.shape[0])
leadership.to_sql('leadership', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 79
# 79

# %%
print(os_contributions.shape[0])
os_contributions.to_sql('contributions', 
               con = engine, 
               index = False, 
               chunksize = 1000, 
               if_exists = 'replace')
# Out:
# 1990
# 1990

# %%
os_contributions.dtypes
# Out:
# org_name    object
# total        int64
# pac          int64
# ndiv         int64
# cid         object
# dtype: object
